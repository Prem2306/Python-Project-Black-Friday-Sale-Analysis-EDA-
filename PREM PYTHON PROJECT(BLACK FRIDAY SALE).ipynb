# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:/Users/DELL/OneDrive/Desktop/black friday project/train.csv")

# %%
df                    #DATA PROCESSING
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()            #DISPLAY FIRST 5 DATA
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.tail()   #DISPLAY LAST 5 DATA
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.shape        #CHECKING SHAPE OF DATASET
# Out:
# (550068, 12)

# %%
df.describe()    #STASTICAL INFORMATION OD NUMERIC DATA
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %% [markdown]
# # DATA PROCESSING

# %%
df.duplicated().sum()       #CHECKING TOTAL NUMBER OF DUPLICATE VALUES
# Out:
# 0

# %%
df.isnull().sum()            #CHECKING TOTAL NUMBER OF NULL VALES
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df=df.copy()

# %% [markdown]
# **CHECKING UNIQUE VALUES**

# %%
df["User_ID"].unique()    #
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df["Product_ID"].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %%
df["Product_Category_2"].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df["Product_Category_3"].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df["Purchase"].nunique()
# Out:
# 18105

# %% [markdown]
# # DATA CLEANING

# %%
pro2=df.groupby(["Gender","Age","Occupation"])["Product_Category_2"].mean()

# %%
pro2.mean()
# Out:
# 10.04789867286193

# %%
df["Product_Category_2"]=df["Product_Category_2"].fillna(10.04)       #FILLING NULL VALUES

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
pro3=df.groupby(["Gender","Age","Occupation"])["Product_Category_3"].mean()

# %%
pro3.mean()
# Out:
# 12.712938288199611

# %%
df["Product_Category_3"]=df["Product_Category_3"].fillna(12.7)     #FILLING NULL VALUES

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0               10.04                12.7      8370
# 1                6.00                14.0     15200
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
plt.figure(figsize=(15,6))
sns.set_style("whitegrid")
sns.histplot(data=df['Purchase'], kde=True)              #MOST OF THE PURCHASES ARE DONE BETWEEN 7000 TO 8500
# Out:
# <AxesSubplot:xlabel='Purchase', ylabel='Count'>

# %%
def single_col_count(list1):
    
    fig,axes=plt.subplots(nrows=len(list1),ncols=1,figsize=(12,34))
    sns.set_style("whitegrid")

    for l in enumerate(list1):  
        s = sns.countplot(ax=axes[l[0]],x=df[l[1]])
        s.set_title((l[0]+1,l[1]))
        
    plt.tight_layout(pad=2)
list1= ['Gender','Age','Occupation','City_Category','Marital_Status','Product_Category_1','Product_Category_2','Product_Category_3']
single_col_count(list1)

# %%
def outliers(list1):
    fig,axes = plt.subplots(nrows=len(list1), ncols=1, figsize=(12,35)) 
    fig.suptitle('Checking Outliers') 
    for i,j in enumerate(list1):
        sns.boxplot(ax=axes[i],data= df,x = j,y='Purchase')
    plt.tight_layout()
        
list1= ['Gender','Age','Occupation','City_Category','Marital_Status','Product_Category_1','Product_Category_2','Product_Category_3']

outliers(list1)

# %%
plt.figure(figsize=(25,9))
sns.countplot(x="Gender",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
dff=df.groupby("Product_ID")[["Purchase"]].count().sort_values(by="Purchase",ascending=False).head()
dff
# Out:
#             Purchase
# Product_ID
# P00265242       1880
# P00025442       1615
# P00110742       1612
# P00112142       1562
# P00057642       1470

# %%
plt.figure(figsize=(25,9))
sns.barplot(x=dff.index,y="Purchase", data=dff)
# Out:
# <AxesSubplot:xlabel='Product_ID', ylabel='Purchase'>

# %%
plt.figure(figsize=(25,9))
sns.lineplot(x="Age",y="Occupation", data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Occupation'>

# %%
plt.figure(figsize=(25,9))
sns.countplot(x="City_Category", data=df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
plt.figure(figsize=(25,9))
sns.boxplot(data=df,x="Product_Category_1",y="Purchase",palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='Product_Category_1', ylabel='Purchase'>

# %%
plt.figure(figsize=(25,9))
sns.lineplot(data=df,x="Age",y="Purchase")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Purchase'>

# %%
city= df.groupby('City_Category').agg({'Purchase':'mean'})
city.plot(subplots=True,kind='pie',figsize=(6,6),cmap='tab20c', shadow=True, autopct='%.1f%%')
plt.title('City category pie chart')
plt.tight_layout()
